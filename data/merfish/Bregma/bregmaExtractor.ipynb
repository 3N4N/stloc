# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
path= "/content/drive/MyDrive/Deconvolution-Free Approaches  Thesis/Moffitt_and_Bambah-Mukku_et_al_merfish_all_cells.csv"
df = pd.read_csv(path)
df.head()
# Out:
#                                 Cell_ID  Animal_ID  ... Ucn3       Vgf
# 0  6749ccb4-2ed1-4029-968f-820a287f43c8          1  ...  0.0  0.000000
# 1  6cac74bd-4ea7-4701-8701-42563cc65eb8          1  ...  0.0  0.000000
# 2  9f29bd57-16a5-4b26-b9f5-37598809da9e          1  ...  0.0  0.000000
# 3  d7eb4e0b-276e-47e3-a55c-0b033180a2fe          1  ...  0.0  0.001138
# 4  54434f3a-eba9-4aec-af35-c9d317ffa1d5          1  ...  0.0  0.029419
#
# [5 rows x 170 columns]

# %%
bregmaValue= -0.04
rslt_df = df.loc[(df['Bregma'] == bregmaValue) & (df['Animal_ID'] == 1)]
rslt_df
fileName= '/content/drive/MyDrive/Deconvolution-Free Approaches  Thesis/'+ 'Bregma_'+str(bregmaValue)+'.xlsx'
rslt_df.to_excel(fileName,index=False)

# %%
animal_df=   df.loc[ (df['Animal_ID'] == 1)]
uniqueDf= animal_df['Bregma'].unique()
uniqueDf
# Out:
# array([ 0.26,  0.21,  0.16,  0.11,  0.06,  0.01, -0.04, -0.09, -0.14,
#        -0.19, -0.24, -0.29])
